# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read csv file

# %%
df=pd.read_csv("bank-full.csv")

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ## Display first 5 Rows

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays previous poutcome   y
# 0  unknown    5   may       261         1     -1        S  unknown  no
# 1  unknown    5   may       151         1     -1        0  unknown  no
# 2  unknown    5   may        76         1     -1        0  unknown  no
# 3  unknown    5   may        92         1     -1        0  unknown  no
# 4  unknown    5   may       198         1     -1        0  unknown  no

# %% [markdown]
# ## Identifying DataTypes of the columns

# %% [markdown]
# |Columns  |DataType                  |
# |---------|--------------------------|
# |Age      |Numeric Attribute         |
# |Job      |Nominal Attribute         |
# |Marital  |Nominal Attribute         |
# |Education|Ordinal Attribute         |
# |Default  |Binary Attribute          |
# |Balance  |Numeric Attribute         |
# |Housing  |Binary Attribute          |
# |Loan     |Binary Attribute          |
# |Day      |Numeric Attribute         |
# |Month    |Ordinal Attribute         |
# |Duration |Numeric Attribute         |
# |Campaign |Discrete Numeric Attribute|
# |Pdays    |Numeric Attribute         |
# |Previous |Numeric Attribute         |
# |Y        |Binary Attribute          |

# %% [markdown]
# ## Number of Rows and Columns

# %%
df.shape
# Out:
# (45211, 17)

# %% [markdown]
# ## Summary of Dataframe

# %%
df.info
# Out:
# <bound method DataFrame.info of        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ## Converting non-numeric values to 0 of "Previous" column

# %%
# Convert only the 'previous' column: non-numeric values become 0
df['previous'] = pd.to_numeric(df['previous'], errors='coerce').fillna(0).astype(int)

#Save the updated DataFrame
df.to_csv('bank-full-updated.csv', index=False)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ## Converting data into Numeric Data

# %%
df = df.apply(pd.to_numeric, errors='ignore')
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ## Calculating Mean

# %%
df.age.mean()
# Out:
# np.float64(40.93621021432837)

# %%
df.balance.mean()
# Out:
# np.float64(1362.2720576850766)

# %%
df.duration.mean()
# Out:
# np.float64(258.1630797814691)

# %%
df.day.mean()
# Out:
# np.float64(15.80641879188693)

# %%
df.pdays.mean()
# Out:
# np.float64(40.19782796222158)

# %%
df.campaign.mean()
# Out:
# np.float64(2.763840658246887)

# %%
df.previous.mean()
# Out:
# np.float64(0.5803233726305546)

# %% [markdown]
# ## Calculating Median

# %%
df.age.median()
# Out:
# np.float64(39.0)

# %%
df.balance.median()
# Out:
# np.float64(448.0)

# %%
df.duration.median()
# Out:
# np.float64(180.0)

# %%
df.day.median()
# Out:
# np.float64(16.0)

# %%
df.pdays.median()
# Out:
# np.float64(-1.0)

# %%
df.campaign.median()
# Out:
# np.float64(2.0)

# %%
df.previous.median()
# Out:
# np.float64(0.0)

# %% [markdown]
# ## Calculating Mode

# %%
df.age.mode()
# Out:
# 0    32
# Name: age, dtype: int64

# %%
df.balance.mode()
# Out:
# 0    0
# Name: balance, dtype: int64

# %%
df.duration.mode()
# Out:
# 0    124
# Name: duration, dtype: int64

# %%
df.day.mode()
# Out:
# 0    20
# Name: day, dtype: int64

# %%
df.pdays.mode()
# Out:
# 0   -1
# Name: pdays, dtype: int64

# %%
df.campaign.mode()
# Out:
# 0    1
# Name: campaign, dtype: int64

# %%
df.previous.mode()
# Out:
# 0    0
# Name: previous, dtype: int64

# %% [markdown]
# ## Summary of Statistics

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ## Calculating Variance and Standard Deviation

# %%
print("\nVariance:")
print(df.var(numeric_only=True))
print("\nStandard Deviation:")
print(df.std(numeric_only=True))
# Out:
# Variance:
# age         1.127581e+02
# balance     9.270599e+06
# day         6.926361e+01
# duration    6.632057e+04
# campaign    9.597733e+00
# pdays       1.002577e+04
# previous    5.305841e+00
# dtype: float64
#
# Standard Deviation:
# age           10.618762
# balance     3044.765829
# day            8.322476
# duration     257.527812
# campaign       3.098021
# pdays        100.128746
# previous       2.303441
# dtype: float64

# %% [markdown]
# ## Calculating Missing Values

# %%
# Missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Histogram

# %%
#Data Distribution
plt.figure(figsize=(10,5))
df[['age', 'balance', 'day', 'duration','pdays','previous']].hist(bins=6, figsize=(14,7))
plt.suptitle("Histograms of Numerical Features")
plt.show()

# %% [markdown]
# ## Visualize Continous Data through Boxplot

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['balance'])
plt.title("Boxplot of Balance")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['age'])
plt.title("Boxplot of Age")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['day'])
plt.title("Boxplot of Day")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['duration'])
plt.title("Boxplot of Duration")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['pdays'])
plt.title("Boxplot of Pdays")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['previous'])
plt.title("Boxplot of Previous")
plt.show()

# %% [markdown]
# ## Visualize Discrete Data through Countplot

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['campaign'])
plt.title("Campaign Distribution")
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Visualization of Nominal Attributes

# %% [markdown]
# ## Job Bar Chart - Count of different jobs types

# %%
plt.figure(figsize=(19,9))
sns.countplot(x='job', data=df, palette='pastel')
plt.title('Distribution of job type')
plt.xlabel('Job')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Marital Bar Chart - Count of Single, Married and Divorced

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='marital', data=df, palette='pastel')
plt.title('Distribution of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Pie Chart - Proportion of different jobs

# %%
plt.figure(figsize=(18,9))
df['job'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightskyblue', 'lightcoral', 'palegreen', 'lightgoldenrodyellow', 'thistle',  'powderblue', 'peachpuff', 'lavender', 'honeydew',  'mistyrose'])
plt.title('Distribution of job type')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Pie Chart - Proportion of Single, Married, and Divorced

# %%
plt.figure(figsize=(10,5))
df['marital'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral','lightskyblue', 'palegreen'])
plt.title('Distribution of Marital Status')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Visualization of Binary Attributes

# %%
df['default'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='default'>

# %%
df['housing'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='housing'>

# %%
df['loan'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='loan'>

# %%
df['y'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='y'>

# %% [markdown]
# # Visualization of Ordinal Attributes

# %% [markdown]
# ## Bar Chart of Education

# %%
order = ['tertiary', 'secondary', 'primary']
sns.countplot(x='education', data=df, order=order, palette='coolwarm')
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Stacked Bar Chart - Education level by Marital Status

# %%
plt.figure(figsize=(14,7))
pd.crosstab(df['marital'], df['education']).plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Education Level by Marital Status')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Age')
plt.show()

# %% [markdown]
# # Visualization of Continuous Attributes

# %% [markdown]
# ## Box plot - Balance Distribution

# %%
sns.boxplot(y='balance', data=df, color='cyan')
plt.title('Balance Distribution ')
plt.ylabel('Balanace')
plt.show()

# %% [markdown]
# ## Boxplot - Duration Distribution

# %%
sns.boxplot(y='duration', data=df, color='cyan')
plt.title('Duration Distribution ')
plt.ylabel('Duration')
plt.show()

# %% [markdown]
# # Visualization of Discrete Attributes

# %% [markdown]
# ## Bar Chart of Campaign Distribution

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='campaign', data=df, palette='rocket')
plt.title('Number of campaign Distribution')
plt.xlabel('Number of Campaign')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Histogram of Campaign Distribution

# %%
sns.histplot(df['campaign'], bins=5, kde=True, color='orange')
plt.title('Number of Campaign Distribution')
plt.xlabel('Campaign')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Relationship Analysis Scatter Plots

# %%
sns.scatterplot(x='balance', y='duration', data=df, color='purple')
plt.title('Balance vs. Duration')
plt.xlabel('Balance')
plt.ylabel('Duration')
plt.show()

# %%
sns.scatterplot(x='balance', y='age', data=df, color='red')
plt.title('Balance vs. Age')
plt.xlabel('Balance')
plt.ylabel('Age')
plt.show()

# %%
sns.scatterplot(x='pdays', y='balance', data=df, color='green')
plt.title('Pdays vs. Balance')
plt.xlabel('Pdays')
plt.ylabel('Balance')
plt.show()

# %%
sns.scatterplot(x='pdays', y='campaign', data=df, color='purple')
plt.title('Pdays vs. campaign')
plt.xlabel('Pdays')
plt.ylabel('Campaign')
plt.show()

# %% [markdown]
# # Report

# %% [markdown]
# # Key Insights from Visualizations
# ### 🔹 Distributions (Histograms & Boxplots)
# Age, Balance, Duration, Pdays, Previous show right-skewed distributions, indicating most values are on the lower end, but some outliers are much higher.
#
# Campaign is also skewed: Most people were contacted only a few times.
#
# ### 🔹 Outliers (Boxplots)
# Balance has numerous high outliers—some clients have extremely high account balances.
#
# Duration and Pdays also have noticeable outliers.
#
# Previous has spikes, suggesting some clients were contacted many times in the past.
#
# ### 🔹 Nominal Attributes (Bar & Pie Charts)
# Most common jobs: blue-collar, management, and technician.
#
# Marital status: married people dominate.
#
# Pie charts confirmed the same patterns with visual proportions.
#
# ### 🔹 Binary Attributes (Bar Charts)
# Default: Vast majority do not have credit in default.
#
# Housing & Loan: Most have housing loans, fewer have personal loans.
#
# Target (y): Majority of clients did not subscribe to a term deposit.
#
# ### 🔹 Correlation Matrix
# Most numeric variables have weak correlations.
#
# Slight positive correlation between pdays and previous.
#
# Duration shows a moderate correlation with the target variable y, which may imply longer calls are associated with positive outcomes.
#
# ## 📈 Patterns Observed
# Longer call duration is often associated with a higher chance of a positive response (y = yes).
#
# Individuals with multiple contacts in past campaigns (previous > 0) might be more likely to respond positively.
#
# Clients who are unmarried or younger may show different behavior trends—needs deeper segmentation.
#
# ### ⚠️ Outliers and Data Issues
# Balance has extreme values—consider log transformation or outlier capping.
#
# Pdays includes -1 values, which often means the client was not previously contacted—this needs special treatment in analysis.
#
# ## 📦 Data Quality
# Very few missing values (mostly handled).
#
# Categorical attributes like job, education, and marital are clearly classified and visualized.
